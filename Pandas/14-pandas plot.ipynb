# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series(np.random.randn(10),index=np.arange(0,100,10))
s.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(10,4).cumsum(0),
                  index = np.arange(0,100,10),
                  columns=['A','B','C','D'])
df.head()
# Out:
#            A         B         C         D
# 0  -0.653014 -0.740294  0.624611 -0.993029
# 10 -0.248818 -2.298833  0.426552 -2.515674
# 20 -0.674251 -1.260736  0.416457 -2.899204
# 30 -0.833553 -2.371828  0.201747 -0.126627
# 40 -1.409386 -3.728744  0.021018  1.474508

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
fig,axes = plt.subplots(2,1) # 2row 1col
data = pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))
data.plot(ax = axes[0],kind='bar')
data.plot(ax = axes[1],kind='barh')
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(6,4),
                  index = ['one','two','three','four','five','six'],
                  columns = pd.Index(['A','B','C','D'],name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.787581  0.940091  0.772742  0.807431
# two    0.752285  0.659287  0.785118  0.967017
# three  0.552489  0.487067  0.265531  0.243608
# four   0.305469  0.602801  0.789044  0.447832
# five   0.740949  0.917601  0.695955  0.349419
# six    0.908680  0.025763  0.650809  0.976287

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
test = pd.read_csv('./test.csv')
test.head()
# Out:
#          date city  temperature  wind
# 0  03/01/2016   TC           36     5
# 1  03/01/2017   TC           25     4
# 2  03/01/2018   TC           27     3
# 3  03/01/2019   TC           26     5
# 4  03/01/2020   TC           25     4

# %%
test.temperature.plot(kind='hist',bins=30) # 壓縮 bins越大圖越小
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
pd.plotting.scatter_matrix(test,color='k',alpha=0.3)
# Out:
# array([[<AxesSubplot:xlabel='temperature', ylabel='temperature'>,
#         <AxesSubplot:xlabel='wind', ylabel='temperature'>],
#        [<AxesSubplot:xlabel='temperature', ylabel='wind'>,
#         <AxesSubplot:xlabel='wind', ylabel='wind'>]], dtype=object)

# %%
test.plot.scatter('wind','date'),
# Out:
# (<AxesSubplot:xlabel='wind', ylabel='date'>,)
