# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = Axes3D(fig)
x = np.arange(-4,4,.25)
y = np.arange(-4,4,.25)
X,Y = np.meshgrid(x,y)
Z = np.sin(np.sqrt(X**2+Y**2))
ax.plot_surface(X,Y,Z,rstride=1,cstride=1,cmap='rainbow') # stride單元格上的大小
ax.contour(X,Y,Z,zdim='z',offset=2,camp='rainbow')
ax.set_zlim(-2,2)
# Out:
# C:\Users\BOOM\AppData\Local\Temp/ipykernel_34728/3662770276.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\BOOM\AppData\Local\Temp/ipykernel_34728/3662770276.py:8: UserWarning: The following kwargs were not used by contour: 'zdim', 'camp'
#   ax.contour(X,Y,Z,zdim='z',offset=2,camp='rainbow')
# (-2.0, 2.0)

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')

# %%
fig = plt.figure()
# ax = fig.gca(projection='3d')
ax = Axes3D(fig)
theta = np.linspace(-4*np.pi,4*np.pi,100)
z = np.linspace(-2,2,100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)

ax.plot(x,y,z)
# Out:
# C:\Users\BOOM\AppData\Local\Temp/ipykernel_34728/2071829955.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
np.random.seed(1)
def randrange(n,vmin,vmax):
  return (vmax-vmin)*np.random.rand(n) + vmin
fig = plt.figure()
ax = fig.gca(projection='3d')
n = 100
for c,m,zlow,zhigh in [('r','o',-50,-25),('b','x',-30,-5)]:
  xs = randrange(n,23,32)
  ys = randrange(n,0,100)
  zs = randrange(n,zlow,zhigh)
  ax.scatter(xs,ys,zs,c=c,marker=m)
# Out:
# C:\Users\BOOM\AppData\Local\Temp/ipykernel_34728/3579270707.py:5: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
np.random.seed(1)
fig = plt.figure()
ax = fig.gca(projection='3d')
n = 100
for c,m,zlow,zhigh in [('r','o',-50,-25),('b','x',-30,-5)]:
  xs = randrange(n,23,32)
  ys = randrange(n,0,100)
  zs = randrange(n,zlow,zhigh)
  ax.scatter(xs,ys,zs,c=c,marker=m)
ax.view_init(40,20)
# Out:
# C:\Users\BOOM\AppData\Local\Temp/ipykernel_34728/2844753656.py:3: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')

for c, z in zip(['r','b','c','y'],[30,20,10,0]):
  xs = np.arange(20)
  ys = np.random.rand(20)
  # ax.bar(xs,ys,zs= z)
  ax.bar(xs,ys,zs= z,zdir='y',color=c,alpha=0.5)
